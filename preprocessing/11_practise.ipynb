# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LinearRegression

# %%
# select data
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# split data
x = df[["total_bill"]]
y = df['tip']

# %%
# train test split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2)

# %%
# # scale the data
# scalar = StandardScaler()
# x_train = scalar.fit_transform(x_train)
# x_test = scalar.fit_transform(x_test)

# %%
import seaborn as sns
sns.histplot(df['tip'], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#select the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
sns.histplot(df['tip'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.histplot(df['tip'])
#
# NameError: name 'sns' is not defined

# %%
model.predict([[20]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.predict([[20]])
#
# NameError: name 'model' is not defined

# %%
#predictions
y_pred = model.predict(x_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #predictions
# ----> 2 y_pred = model.predict(x_test)
#       3 y_pred
#
# NameError: name 'model' is not defined

# %%
y_pred = model.predict([[80]])
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y_pred = model.predict([[80]])
#       2 y_pred
#
# NameError: name 'model' is not defined

# %%
# evaluation the model
from sklearn.metrics import mean_squared_error, r2_score
print('MSE', mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # evaluation the model
#       2 from sklearn.metrics import mean_squared_error, r2_score
# ----> 3 print('MSE', mean_squared_error(y_test, y_pred))
#       4 print("R2:", r2_score(y_test, y_pred))
#
# NameError: name 'y_test' is not defined

# %%
# evaluation the model
from sklearn.metrics import mean_squared_error, r2_score
print('MSE', mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 # evaluation the model
#       2 from sklearn.metrics import mean_squared_error, r2_score
# ----> 3 print('MSE', mean_squared_error(y_test, y_pred))
#       4 print("R2:", r2_score(y_test, y_pred))
#
# File c:\Users\Muhammad Zeeshan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\Muhammad Zeeshan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:497, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     492     if not squared:
#     493         return root_mean_squared_error(
#     494             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     495         )
# --> 497 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     498     y_true, y_pred, multioutput
#     499 )
#     500 check_consistent_length(y_true, y_pred, sample_weight)
#     501 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File c:\Users\Muhammad Zeeshan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:102, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      68 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      69     """Check that y_true and y_pred belong to the same regression task.
#      70
#      71     Parameters
#    (...)
#     100         correct keyword.
#     101     """
# --> 102     check_consistent_length(y_true, y_pred)
#     103     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     104     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File c:\Users\Muhammad Zeeshan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [196, 1]
